# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

# special matplotlib argument for improved plots
from matplotlib import rcParams

#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'

# %%
# scaled : vary all by calculated variance, shift so that hte lowest is 0

# %%
scaled = np.loadtxt("../pipeline/result26/log.evals")
scaled.shape
# Out:
# (2992630,)

# %%
scaled = scaled.reshape([101,10,2963])

# %%
# for each anchorset, print out number of points with error within threshold, norm of error, and average of error
for anchor_set in scaled[:30]:
    for config in anchor_set:
        print sum(config <= 1e-7),
    print np.linalg.norm(anchor_set), np.sum(anchor_set)/len(anchor_set)
# Out:
# 2963 2963 2963 2963 2963 2963 2963 2963
# 2963 2963 0.0 0.0
# 2962 2962 2875 2962 2962 2963
# 2962 2962 2962 2962 2.30073515483e-06 1.01141815316e-05
# 2962 2962 2872 2962 2962
# 2963 2962 2962 2962 2962 2.3308589471e-06 1.02824003577e-05
# 2962 2962 2874
# 2962 2962 2963 2962 2962 2962 2962 2.31446290007e-06 1.01920602737e-05
# 2962 2962
# 2872 2962 2962 2963 2962 2962 2962 2962 2.33467777034e-06 1.03130247086e-05
# 2962
# 2962 2864 2962 2962 2963 2962 2962
# 2962 2962 2.36690638419e-06 1.05020460413e-05
# 2962 2962 2961 2955 2962 2962
# 2962 2962 2963 2962 1.5297066228e-06 1.07289056119e-05
# 2962 2962 2962
# 2956 2962 2962 2962 2962 2963 2962 1.5853985537e-06 1.13351104895e-05
# 2962
#  2962 2961 2955 2962 2962 2962 2962 2963
# 2962 1.53242339135e-06 1.07519612694e-05
# 2962 2962 2962 2956 2962 2962 2962 2962 2963
# 2962 1.57575427581e-06 1.12101934242e-05
# 2962 2962 2962 2957 2962 2962 2962
# 2962 2963 2962 1.56202003497e-06 1.10803683092e-05
# ...

# %%
for anchor_set in scaled[:30]:
    for config in anchor_set:
        plt.hist(config, bins=10**np.linspace(-10,-3,50))
        plt.gca().set_xscale("log")
    plt.show()

# %%
# dirchlet : for each row, sample Dir(alpha+observations), 
# with alpha = sum over columns, observations = that row in the q matrix

#     new_config = np.zeros(M.shape)
#     col_sums = M.sum(0)
#     for i,row in enumerate(M):
#         alphas = row + col_sums
#         # print row, col_sums, alphas
#         new_config[i] = np.random.dirichlet(alphas)

# %%
dirch = np.loadtxt("../pipeline/result26/dirichlet/log.evals")
dirch.shape
# Out:
# (2992630,)

# %%
dirch = dirch.reshape([101,10,2963])

# %%
for anchor_set in dirch[:30]:
    for config in anchor_set:
        print sum(config <= 1e-5),
    print np.linalg.norm(anchor_set), np.sum(anchor_set)/len(anchor_set)
# Out:
# 2963 2963 2963 2963 2963 2963 2963 2963 2963 2963 0.0 0.0
# 868
#  735 930 937 820 1108 923 857 710
# 875 0.00432170531237 0.0516280731002
# 881 735 946 922 830 1023 919 881 712
# 905 0.00422417728568 0.0511234412906
# 858 628 948 917 832 1003 911 881 697 897 0.00460484750621 0.0531158642652
# 880
#  743 954 885 779 1000 929 902 703 867 0.00424823138802 0.0513821724202
# 889
# 727 964 944 821 1007 881 886
# 747 930 0.00418354220153 0.0508129504173
# 897 977 986 872 832 835 839
# 894 812 832 0.0039568068949 0.0491732096923
# 900 963 1046 878 832 840 852
# 896 792 853 0.00401740237739 0.0496225997484
# 941 995 972 864 849 829 826
# 911 812 913 0.00393902521453 0.0488710991876
# 907 1000 965 838 807
#  846 825 882 776 833 0.00400512649341 0.0496527160889
# 910 974 1018 879 877
# 832 865 936 792 950 0.00397655359313 0.0489389674463
# 968 848 910 760 897 899
#  884 861 848 879 0.00399089261809 0.0493606866134
# 951 858 941 768 900
# 914 847 880 869 879 0.00393471523441 0.0489819834602
# ...

# %%
for anchor_set in dirch[:30]:
    for config in anchor_set:
        plt.hist(config, bins=10**np.linspace(-10,0,50))
        plt.gca().set_xscale("log")
    plt.show()

# %%
scaled2 = np.loadtxt("../pipeline/result26/scale2/log.evals")
scaled2.shape
# Out:
# (2992630,)

# %%
scaled2_orig = np.loadtxt("../pipeline/result26/scale2/log.evals_configs")
scaled2_orig.shape
# Out:
# (592600,)

# %%
scaled2_orig = scaled2_orig.reshape([20, 10, 2963])

# %%
for anchor_set in scaled2_orig[:6]:
    for config in anchor_set:
        print sum(config <= 1e-7),
    print np.linalg.norm(anchor_set), np.sum(anchor_set)/len(anchor_set)
# Out:
# 2962 2933 2962 2962 2809 2962 2962
# 2949 2963 2962 3.87460178122e-06 2.8367911636e-05
# 2962 2962 2962 2962 2962
# 2962 2962 2962 2962 2963 9.46616627889e-07 4.76463337415e-06
# 2962 2962 2692 2954
# 2961 2962 2641 2963 2962 2955 5.13387719947e-06 3.71655599394e-05
# 2962 2962
# 2962 2962 2962 2939 2962 2963 2962 2962 1.82559131573e-06 9.1817057012e-06
# 2962
# 2961 2962 2962 2956 2962 2962 2962 2963 2962 1.66071298804e-06 1.32721594283e-05
# 2962
# 2962 2962 2963 2962 2917 2958 2961 2962 2962 2.27396393154e-06 1.41407496247e-05

# %%
for anchor_set in scaled2_orig[:6]:
    for config in anchor_set:
        plt.hist(config, bins=10**np.linspace(-10,0,50))
        plt.gca().set_xscale("log")
    plt.show()

# %%
dir2_orig = np.loadtxt("../pipeline/result26/dirichlet2/log.evals_configs")
dir2_orig.shape
# Out:
# (592600,)

# %%
dir2_orig = dir2_orig.reshape([20, 10, 2963])

# %%
for anchor_set in dir2_orig[:6]:
    for config in anchor_set:
        print sum(config <= 1e-5),
    print np.linalg.norm(anchor_set), np.sum(anchor_set)/len(anchor_set)
# Out:
# 806 1030 717 828 970 931 936 701
# 1070 941 0.0039299656139 0.0490233444839
# 872 698 887 974 847
# 936 934 835 763 926 0.0043395055064 0.0514992665178
# 849 809 775
# 891 871 989 903 854 941 1011 0.00373618598765 0.0477798811821
# 893
#  860 871 927 887 938 905 778 898
# 965 0.00377769386845 0.0482177611937
# 938 814 891 871 972 737 852 736
# 887 904 0.00411318019888 0.0506924115335
# 929 848 775 783 805 936
# 930 845 860 902 0.00422241822767 0.0509065033109

# %%
for anchor_set in dir2_orig[:6]:
    for config in anchor_set:
        plt.hist(config, bins=10**np.linspace(-10,0,50))
        plt.gca().set_xscale("log")
    plt.show()

# %%
for anchor_set in scaled[:30]:
    for config in anchor_set:
        plt.hist(config, bins=10**np.linspace(-10,-3,50))
        plt.gca().set_xscale("log")
plt.show()

for anchor_set in scaled2_orig[:6]:
    for config in anchor_set:
        plt.hist(config, bins=10**np.linspace(-10,0,50))
        plt.gca().set_xscale("log")
plt.show()
