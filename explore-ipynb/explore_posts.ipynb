# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline 

# special matplotlib argument for improved plots
from matplotlib import rcParams

#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'

# %%
posts_file = "../pipeline/get_q/all_posts.txt"

# %%
posts = []
with open(posts_file, "r") as f:
    for line in f:
        posts.append(line)

# %%
print posts[0]
print posts[0].split()
# Out:
#  when lc has watched simpson movie he was laughing all the way through ,      later that evening in floods of tears at a sad bit ( when marge left homer ) anyway tried to remind him of funny bit and went to bed slightly better      then he watched mary poppins ,again later he was in floods of tears ( when mary poppins sang about the bird lady tuppence a bag )      what im very worried about is why he gets sooooo sad , he came home from school really sad again he said he remebered something sad from ,,whatever he watched etc      and it keeps happening            and i do try to keep the chin up attitude just wondered if anything else is worrying ,he is having probs with bullying   but he seems to have bounced back from that ,now the lads invovled are being nice so he says        help !!!!!!        Edited by Rosebud, 27 January 2008 - 06:50 PM.
#
# ...

# %%
posts_lengths = [len(post.split()) for post in posts]
print posts_lengths
# Out:
# [159, 78, 77, 17, 66, 41, 21, 48, 43, 17, 53, 97, 72, 967, 49, 165, 350, 47, 165, 78, 159, 6, 60, 39, 352, 49, 207, 548, 222, 53, 196, 9, 271, 391, 92, 225, 9, 115, 84, 52, 63, 84, 50, 145, 172, 241, 26, 61, 179, 32, 33, 19, 23, 73, 9, 57, 49, 52, 38, 31, 34, 46, 120, 508, 248, 379, 181, 9, 4, 22, 97, 70, 176, 15, 45, 53, 115, 67, 251, 120, 35, 37, 47, 109, 45, 184, 42, 67, 18, 47, 95, 93, 70, 12, 328, 96, 19, 11, 75, 125, 12, 18, 49, 3, 14, 10, 11, 17, 24, 77, 29, 31, 51, 121, 36, 89, 166, 127, 39, 29, 72, 157, 97, 41, 448, 192, 36, 16, 40, 13, 14, 229, 31, 51, 88, 105, 7, 39, 149, 99, 74, 207, 129, 107, 41, 15, 53, 16, 198, 28, 61, 130, 30, 89, 30, 24, 11, 27, 91, 145, 139, 80, 47, 186, 46, 33, 69, 57, 158, 28, 57, 61, 64, 176, 280, 142, 381, 43, 180, 158, 191, 204, 114, 181, 102, 65, 110, 93, 49, 487, 20, 215, 68, 104, 27, 16, 82, 42, 7, 49, 490, 17, 8, 165, 32, 248, 166, 242, 43, 69, 119, 47, 68, 254, 48, 244, 181, 54, 50, 66, 50, 37, 115, 88, 226, 260, 107, 168, 13, 37, 42, 9, 4
# ...

# %%
print sum(posts_lengths)/len(posts_lengths)
# Out:
# 105

# %%
plt.hist(posts_lengths, bins=100)
# Out:
# (array([  1.02168000e+05,   2.70060000e+04,   8.50300000e+03,
#           3.16500000e+03,   1.46800000e+03,   7.44000000e+02,
#           4.51000000e+02,   2.54000000e+02,   1.56000000e+02,
#           9.30000000e+01,   8.10000000e+01,   4.50000000e+01,
#           5.30000000e+01,   2.40000000e+01,   2.30000000e+01,
#           1.40000000e+01,   1.60000000e+01,   1.00000000e+01,
#           8.00000000e+00,   1.00000000e+01,   6.00000000e+00,
#           8.00000000e+00,   6.00000000e+00,   2.00000000e+00,
#           4.00000000e+00,   2.00000000e+00,   2.00000000e+00,
#           5.00000000e+00,   1.00000000e+00,   2.00000000e+00,
#           3.00000000e+00,   2.00000000e+00,   3.00000000e+00,
#           3.00000000e+00,   2.00000000e+00,   3.00000000e+00,
#           3.00000000e+00,   2.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   1.00000000e+00,
# ...

# %%
posts_lengths_short = filter(lambda x: x < 200, posts_lengths)

# %%
plt.hist(posts_lengths_short)
# Out:
# (array([ 24250.,  24727.,  19849.,  15305.,  11615.,   8897.,   6952.,
#           5633.,   4523.,   3616.]),
#  array([   0. ,   19.9,   39.8,   59.7,   79.6,   99.5,  119.4,  139.3,
#          159.2,  179.1,  199. ]),
#  <a list of 10 Patch objects>)

# %%
import scipy.io

# %%
s = scipy.io.loadmat("../pipeline/cui_counter.mat.trunc.mat")
m = s['M']

# %%
print m
# Out:
#   (91, 0)	1.0
#   (421, 0)	1.0
#   (468, 0)	1.0
#   (659, 0)	1.0
#   (1032, 0)	1.0
#   (1440, 0)	1.0
#   (1521, 0)	1.0
#   (1665, 0)	1.0
#   (1708, 0)	1.0
#   (1847, 0)	1.0
#   (2057, 0)	1.0
#   (2147, 0)	1.0
#   (2728, 0)	1.0
#   (2874, 0)	1.0
#   (2909, 0)	1.0
#   (91, 1)	1.0
#   (180, 1)	1.0
#   (250, 1)	1.0
#   (413, 1)	1.0
#   (421, 1)	1.0
#   (445, 1)	1.0
#   (586, 1)	1.0
#   (720, 1)	1.0
#   (850, 1)	1.0
#   (1020, 1)	1.0
#   :	:
#   (1308, 245715)	1.0
#   (1331, 245715)	1.0
#   (1950, 245715)	1.0
#   (2295, 245715)	1.0
#   (2333, 245715)	1.0
#   (2629, 245715)	1.0
#   (2728, 245715)	1.0
#   (7, 245716)	1.0
#   (50, 245716)	1.0
#   (91, 245716)	1.0
#   (116, 245716)	1.0
#   (127, 245716)	1.0
#   (243, 245716)	1.0
#   (418, 245716)	1.0
#   (478, 245716)	1.0
#   (487, 245716)	1.0
#   (510, 245716)	1.0
#   (576, 245716)	1.0
#   (689, 245716)	1.0
#   (998, 245716)	1.0
#   (1229, 245716)	1.0
#   (1502, 245716)	1.0
#   (2012, 245716)	1.0
#   (2593, 245716)	1.0
# ...

# %%
words_sum = [row.sum() for row in m]
print words_sum
# Out:
# [143.0, 139.0, 207.0, 81.0, 95.0, 52.0, 1648.0, 966.0, 3230.0, 128.0, 77.0, 53.0, 52.0, 292.0, 62.0, 179.0, 81.0, 7466.0, 194.0, 196.0, 1203.0, 90.0, 182.0, 194.0, 106.0, 119.0, 465.0, 55.0, 936.0, 199.0, 80.0, 139.0, 61.0, 3633.0, 185.0, 116.0, 7282.0, 597.0, 2703.0, 182.0, 1685.0, 1009.0, 410.0, 1388.0, 908.0, 207.0, 51.0, 54.0, 593.0, 130